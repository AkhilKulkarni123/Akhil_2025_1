# %% [markdown]
# ---
# comments: True
# layout: post
# title: AP CSP Supplemental Practice Exam — Full Performance Report
# description: A complete review of my performance on the Supplemental Practice MCQ (70 questions) and the Written Response Supplemental Practice FRQ — including missed-question analysis, FRQ self-grading against the CollegeBoard rubric, anticipated FRQ-style questions, and an exam-day strategy for the actual AP CSP FRQ.
# permalink: /apcsp/supplemental-exam-review
# categories: [AP CSP]
# author: Akhil Kulkarni
# ---

# %% [markdown]
# <style>
# /* ─────────────────────────────────────────────
#    Page background + base typography
#    ───────────────────────────────────────────── */
# .post-content {
#   background: linear-gradient(180deg, #0b1020 0%, #0e1430 100%) !important;
#   color: #e0e6ff !important;
#   padding: 2rem 1.4rem 3rem 1.4rem !important;
#   border-radius: 12px;
#   font-family: 'Inter', 'Segoe UI', system-ui, sans-serif;
#   line-height: 1.65;
# }
# .post-content p, .post-content li {
#   color: #d6dcf0 !important;
#   font-size: 1.02rem;
# }
# .post-content strong, .post-content b {
#   color: #ffffff !important;
# }
# .post-content a { color: #8ab4ff !important; }
#
# /* ─────────────────────────────────────────────
#    Headings
#    ───────────────────────────────────────────── */
# .post-content h1 {
#   font-size: 2.1rem !important;
#   color: #ffffff !important;
#   border-bottom: 2px solid #4f6dff;
#   padding-bottom: 0.45rem;
#   margin-top: 2.6rem !important;
#   letter-spacing: -0.01em;
# }
# .post-content h2 {
#   color: #ffffff !important;
#   font-size: 1.55rem !important;
#   margin-top: 2rem !important;
#   letter-spacing: -0.005em;
# }
# .post-content h3 {
#   color: #c9d6ff !important;
#   font-size: 1.18rem !important;
#   margin-top: 1.6rem !important;
# }
#
# /* ─────────────────────────────────────────────
#    Hero header card
#    ───────────────────────────────────────────── */
# .hero {
#   background: linear-gradient(135deg, #1a2a6c 0%, #4b1f8c 50%, #b21f5c 100%);
#   border-radius: 16px;
#   padding: 2rem 1.8rem;
#   margin: 0.8rem 0 2rem 0;
#   box-shadow: 0 10px 30px rgba(0,0,0,0.5), 0 0 0 1px rgba(255,255,255,0.05) inset;
#   text-align: center;
#   color: #ffffff;
#   position: relative;
#   overflow: hidden;
# }
# .hero::before {
#   content: "";
#   position: absolute;
#   inset: 0;
#   background-image:
#     radial-gradient(2px 2px at 20% 30%, #fff 50%, transparent),
#     radial-gradient(1px 1px at 80% 20%, #fff 50%, transparent),
#     radial-gradient(1px 1px at 60% 70%, #fff 50%, transparent),
#     radial-gradient(2px 2px at 40% 80%, #fff 50%, transparent),
#     radial-gradient(1px 1px at 90% 60%, #fff 50%, transparent),
#     radial-gradient(1px 1px at 10% 80%, #fff 50%, transparent);
#   opacity: 0.55;
#   pointer-events: none;
# }
# .hero h1.hero-title {
#   font-size: 2.4rem;
#   margin: 0 0 0.4rem 0 !important;
#   border: none !important;
#   color: #ffffff !important;
#   letter-spacing: -0.02em;
#   position: relative;
# }
# .hero .hero-sub {
#   font-size: 1.05rem;
#   color: #f0e9ff !important;
#   opacity: 0.92;
#   margin-bottom: 1.2rem;
#   position: relative;
# }
# .hero .hero-meta {
#   display: inline-flex;
#   flex-wrap: wrap;
#   gap: 0.5rem;
#   justify-content: center;
#   position: relative;
# }
# .hero .pill {
#   background: rgba(255,255,255,0.13);
#   border: 1px solid rgba(255,255,255,0.25);
#   padding: 0.35rem 0.8rem;
#   border-radius: 999px;
#   font-size: 0.85rem;
#   color: #fff;
#   backdrop-filter: blur(6px);
# }
#
# /* ─────────────────────────────────────────────
#    Score / stat cards
#    ───────────────────────────────────────────── */
# .stat-grid {
#   display: grid;
#   grid-template-columns: repeat(auto-fit, minmax(160px, 1fr));
#   gap: 1rem;
#   margin: 1.2rem 0 1.5rem 0;
# }
# .stat-card {
#   background: linear-gradient(160deg, #1a2046 0%, #232a5c 100%);
#   border: 1px solid #2c356b;
#   border-radius: 12px;
#   padding: 1rem 1rem;
#   text-align: center;
#   box-shadow: 0 4px 14px rgba(0,0,0,0.35);
# }
# .stat-card .stat-label {
#   font-size: 0.78rem;
#   letter-spacing: 0.08em;
#   text-transform: uppercase;
#   color: #8a96cc;
# }
# .stat-card .stat-value {
#   font-size: 1.9rem;
#   font-weight: 700;
#   color: #ffffff;
#   margin-top: 0.25rem;
# }
# .stat-card.good  .stat-value { color: #4ade80; }
# .stat-card.warn  .stat-value { color: #fbbf24; }
# .stat-card.bad   .stat-value { color: #f87171; }
# .stat-card.score .stat-value {
#   background: linear-gradient(90deg, #4ade80, #38bdf8);
#   -webkit-background-clip: text;
#   background-clip: text;
#   -webkit-text-fill-color: transparent;
# }
#
# /* ─────────────────────────────────────────────
#    Progress bars
#    ───────────────────────────────────────────── */
# .bar-row {
#   display: grid;
#   grid-template-columns: 220px 1fr 60px;
#   gap: 0.8rem;
#   align-items: center;
#   margin: 0.45rem 0;
#   font-size: 0.95rem;
# }
# .bar-row .bar-label { color: #cdd6f4; }
# .bar-row .bar-value { color: #cdd6f4; text-align: right; font-variant-numeric: tabular-nums; }
# .bar-track {
#   background: #161a35;
#   border-radius: 999px;
#   height: 14px;
#   overflow: hidden;
#   border: 1px solid #232a5c;
# }
# .bar-fill {
#   height: 100%;
#   border-radius: 999px;
#   background: linear-gradient(90deg, #4ade80, #38bdf8);
# }
# .bar-fill.warn { background: linear-gradient(90deg, #fbbf24, #f59e0b); }
# .bar-fill.bad  { background: linear-gradient(90deg, #f87171, #ef4444); }
# .bar-fill.full { background: linear-gradient(90deg, #4ade80, #22c55e); }
#
# /* ─────────────────────────────────────────────
#    Callout boxes
#    ───────────────────────────────────────────── */
# .callout {
#   border-radius: 10px;
#   padding: 0.95rem 1.1rem;
#   margin: 1rem 0;
#   border: 1px solid;
#   background: #161a35;
# }
# .callout strong { display: block; margin-bottom: 0.3rem; }
# .callout.note    { border-color: #4f6dff; background: #1a2046; }
# .callout.success { border-color: #22c55e; background: #14281f; }
# .callout.warn    { border-color: #f59e0b; background: #2a1f0e; }
# .callout.danger  { border-color: #ef4444; background: #2a1414; }
#
# /* ─────────────────────────────────────────────
#    Question cards (missed MCQs / anticipated FRQs)
#    ───────────────────────────────────────────── */
# .qcard {
#   background: linear-gradient(160deg, #1a1f44 0%, #1f2658 100%);
#   border: 1px solid #2c356b;
#   border-left: 5px solid #f87171;
#   border-radius: 12px;
#   padding: 1rem 1.2rem;
#   margin: 1rem 0;
#   box-shadow: 0 4px 14px rgba(0,0,0,0.3);
# }
# .qcard.warn { border-left-color: #fbbf24; }
# .qcard.fix  { border-left-color: #4ade80; }
# .qcard h3 { margin-top: 0 !important; color: #ffffff !important; }
# .qcard .badge {
#   display: inline-block;
#   font-size: 0.72rem;
#   padding: 0.2rem 0.55rem;
#   border-radius: 999px;
#   margin-left: 0.5rem;
#   letter-spacing: 0.05em;
#   text-transform: uppercase;
#   font-weight: 600;
# }
# .qcard .badge.miss { background: #4a1414; color: #fca5a5; border: 1px solid #ef4444; }
# .qcard .badge.shaky { background: #3a2a0e; color: #fcd34d; border: 1px solid #f59e0b; }
#
# /* ─────────────────────────────────────────────
#    Rubric / general tables
#    ───────────────────────────────────────────── */
# .post-content table {
#   border-collapse: separate;
#   border-spacing: 0;
#   width: 100%;
#   margin: 1.4rem 0;
#   border-radius: 12px;
#   overflow: hidden;
#   box-shadow: 0 4px 18px rgba(0,0,0,0.4);
# }
# .post-content table th {
#   background: linear-gradient(180deg, #2a3275 0%, #232a5c 100%) !important;
#   color: #ffffff !important;
#   padding: 0.75rem 1rem !important;
#   border: 1px solid #2c356b !important;
#   font-weight: 700;
#   text-align: left;
#   letter-spacing: 0.02em;
# }
# .post-content table td {
#   background: #161a35 !important;
#   color: #d6dcf0 !important;
#   padding: 0.65rem 1rem !important;
#   border: 1px solid #232a5c !important;
# }
# .post-content table tr:nth-child(even) td { background: #1a2046 !important; }
# .post-content table tr:hover td { background: #232a5c !important; }
#
# /* ─────────────────────────────────────────────
#    Code blocks (markdown ```...```)
#    ───────────────────────────────────────────── */
# .post-content .highlight,
# .post-content pre,
# .post-content pre code,
# .post-content .highlight pre {
#   background: #0c1126 !important;
#   color: #e6e9ff !important;
#   border-radius: 10px;
#   border: 1px solid #1f274d;
# }
# .post-content pre {
#   padding: 1rem 1.1rem !important;
#   overflow-x: auto;
# }
#
# /* ─────────────────────────────────────────────
#    Inline code
#    ───────────────────────────────────────────── */
# .post-content code {
#   background: #1a2046;
#   color: #c4d0ff;
#   padding: 0.1rem 0.4rem;
#   border-radius: 4px;
#   font-size: 0.92em;
#   border: 1px solid #232a5c;
# }
#
# /* ─────────────────────────────────────────────
#    Section divider
#    ───────────────────────────────────────────── */
# .divider {
#   display: flex;
#   align-items: center;
#   gap: 0.7rem;
#   margin: 2.4rem 0 1rem 0;
#   color: #8ab4ff;
#   font-size: 0.85rem;
#   letter-spacing: 0.18em;
#   text-transform: uppercase;
# }
# .divider::before, .divider::after {
#   content: "";
#   flex: 1;
#   height: 1px;
#   background: linear-gradient(90deg, transparent, #4f6dff, transparent);
# }
#
# /* ─────────────────────────────────────────────
#    Blockquote
#    ───────────────────────────────────────────── */
# .post-content blockquote {
#   border-left: 4px solid #8ab4ff !important;
#   background: linear-gradient(90deg, #1a2046 0%, #161a35 100%) !important;
#   padding: 0.9rem 1.3rem !important;
#   margin: 1.4rem 0 !important;
#   border-radius: 0 10px 10px 0;
#   font-style: italic;
# }
# .post-content blockquote p { color: #cdd6f4 !important; margin: 0 !important; }
#
# /* ─────────────────────────────────────────────
#    Two-column comparison block
#    ───────────────────────────────────────────── */
# .compare {
#   display: grid;
#   grid-template-columns: 1fr 1fr;
#   gap: 1rem;
#   margin: 1rem 0;
# }
# @media (max-width: 720px) { .compare { grid-template-columns: 1fr; } }
# .compare .card {
#   background: #161a35;
#   border: 1px solid #2c356b;
#   border-radius: 10px;
#   padding: 1rem 1.1rem;
# }
# .compare .card h4 {
#   margin: 0 0 0.4rem 0;
#   color: #ffffff;
#   font-size: 1rem;
# }
# .compare .card.good { border-left: 4px solid #22c55e; }
# .compare .card.bad  { border-left: 4px solid #ef4444; }
#
# /* ─────────────────────────────────────────────
#    Tag chips
#    ───────────────────────────────────────────── */
# .tag {
#   display: inline-block;
#   background: #1a2046;
#   color: #c4d0ff;
#   border: 1px solid #2c356b;
#   padding: 0.18rem 0.55rem;
#   border-radius: 999px;
#   font-size: 0.78rem;
#   margin: 0.15rem 0.2rem 0.15rem 0;
# }
# .tag.green { color: #4ade80; border-color: #22c55e; background: #102a1c; }
# .tag.red   { color: #fca5a5; border-color: #ef4444; background: #2a1414; }
# .tag.gold  { color: #fcd34d; border-color: #f59e0b; background: #2a1f0e; }
# </style>

# %% [markdown]
# <div class="hero">
#   <h1 class="hero-title">🔭 AP CSP Supplemental Practice Exam</h1>
#   <div class="hero-sub">A complete performance breakdown — MCQ analysis, FRQ self-grade, and exam-day strategy.</div>
#   <div class="hero-meta">
#     <span class="pill">📅 May 8, 2026</span>
#     <span class="pill">👤 Akhil Kulkarni</span>
#     <span class="pill">📝 70 MCQ + Written FRQ</span>
#     <span class="pill">🎯 Goal: Full Score</span>
#   </div>
# </div>

# %% [markdown]
# ## Overview
#
# <div class="callout note">
# <strong>What's in this blog</strong>
# A focused review-and-prep document for the actual AP CSP exam. It records what I got wrong on the MCQ (and why), self-grades the FRQ against the official CollegeBoard rubric, anticipates the exact follow-up questions CollegeBoard could ask about my FRQ code, and locks in an exam-day strategy.
# </div>
#
# **Exams completed on the CollegeBoard practice platform**
#
# <span class="tag">Supplemental Practice Exam — MCQ (70 Q)</span>
# <span class="tag">Written Response Supplemental Practice Exam — FRQ</span>
# <span class="tag green">PPR submission ready</span>

# %% [markdown]
# <div class="divider">Section 1 · MCQ Performance</div>
#
# # 📊 MCQ Performance Report
#
# <div class="stat-grid">
#   <div class="stat-card"><div class="stat-label">Total Questions</div><div class="stat-value">70</div></div>
#   <div class="stat-card good"><div class="stat-label">Correct</div><div class="stat-value">~65</div></div>
#   <div class="stat-card bad"><div class="stat-label">Incorrect</div><div class="stat-value">~5</div></div>
#   <div class="stat-card score"><div class="stat-label">Score</div><div class="stat-value">~92.9%</div></div>
# </div>
#
# <div class="bar-row">
#   <div class="bar-label">Correct</div>
#   <div class="bar-track"><div class="bar-fill" style="width:93%"></div></div>
#   <div class="bar-value">93%</div>
# </div>
# <div class="bar-row">
#   <div class="bar-label">Incorrect</div>
#   <div class="bar-track"><div class="bar-fill bad" style="width:7%"></div></div>
#   <div class="bar-value">7%</div>
# </div>
#
# <div class="callout note">
# <strong>Bottom line</strong>
# Strong baseline (~93%), but a recurring theme in the missed questions — <b>careful tracing of code, flowcharts, and graphs</b> — needs deliberate work before exam day. The mistakes were not conceptual; they were precision mistakes.
# </div>

# %% [markdown]
# ## Questions / Topics That Were Challenging
#
# Each missed (or shaky) question is broken down below — **what it tested**, **the trap I fell for**, and **the right way to think about it next time**.

# %% [markdown]
# <div class="qcard">
# <h3>Q5 — Code Maintainability / Abstraction <span class="badge miss">Missed</span></h3>
#
# - **What it tested:** Identifying the *correct* application of abstraction to remove duplicated logic.
# - **My (wrong) instinct:** Selected "putting each duplicated segment into a separate procedure called once."
# - **Why that's wrong:** That just *moves* the duplication — every duplicated segment becomes its own procedure. The logic is still copy-pasted, only now spread across multiple function definitions.
# - **Correct answer:** All duplicated code goes into **ONE procedure**, which is then **called multiple times** wherever that logic is needed.
# - **Takeaway:** Abstraction = *one* function reused, not *many* near-identical functions. The right answer leaves me editing one place; the wrong answer leaves me editing many.
# - **How I'll improve:** Whenever a question mentions "reduce duplication / improve maintainability," I'll mentally check: *does this answer leave me with one source of truth?* If not, it's wrong.
#
# </div>

# %% [markdown]
# <div class="qcard">
# <h3>Q12 — Flowchart Logic (Missing Step) <span class="badge miss">Missed</span></h3>
#
# - **What it tested:** Filling in the missing condition in a nested-IF flowchart.
# - **The trap:** Easy to confuse `ounces > 10` with `ounces ≥ 10`, or to add an unnecessary `OR` because a later branch happens to have a similar condition.
# - **Correct answer:** The condition was simply `ounces > 10` (strict greater-than, no OR).
# - **Why I wavered:** Nested-IF flowcharts have a confusing visual layout — the "yes" and "no" arrows from each diamond can feel like they overlap with conditions later in the chart.
# - **How I'll improve:** I will redraw the flowchart on scratch paper as a series of indented `if/else` statements before answering. That converts the visual into something I can trace line-by-line, like normal code.
#
# </div>

# %% [markdown]
# <div class="qcard">
# <h3>Q28 — Token Display Procedure Bug <span class="badge miss">Missed</span></h3>
#
# - **What it tested:** Finding which call to `displayTokens(n)` would expose a bug in a procedure that distributes tokens of value 10, 5, and 1.
# - **The bug:** The third loop, `REPEAT UNTIL (total = 0)` for the value-1 tokens, is **missing a `total ← total − 1` decrement** inside the loop body. So whenever any non-zero remainder reaches that loop, it loops forever.
#
# <div class="compare">
#   <div class="card good">
#     <h4>✅ displayTokens(80, 35, 5)</h4>
#     Value-10 and value-5 loops drain <code>total</code> exactly to <code>0</code> <i>before</i> the buggy third loop ever runs — so the missing decrement doesn't matter.
#   </div>
#   <div class="card bad">
#     <h4>❌ displayTokens(19)</h4>
#     After 1×TEN (<code>total = 9</code>) and 1×FIVE (<code>total = 4</code>), the third loop runs with <code>total = 4</code>. With no decrement, it loops forever.
#   </div>
# </div>
#
# - **Takeaway:** "Find the bug" questions are really "find the input that *triggers* the bug." I should search for inputs that leave a non-zero remainder going into the buggy block, not just plug in numbers and hope something breaks.
# - **Mental checklist for buggy-procedure questions:** (1) *Where* could a bug hide? (2) *Which input* would force execution through that path? (3) *What state* would the variables be in at that point?
#
# </div>

# %% [markdown]
# <div class="qcard warn">
# <h3>Q27 &amp; Q40 — Robot Grid Navigation <span class="badge shaky">Shaky</span></h3>
#
# - **What they tested:** Tracing robot procedures (`skipLeft`, `skipRight`, `MOVE_FORWARD` after rotations) on a grid.
# - **The recurring error:** Losing track of the robot's **orientation** after each rotation. After two `ROTATE_LEFT`s, the robot is facing the opposite direction, but in the heat of tracing it's easy to keep treating "forward" as whatever direction it started.
# - **Strategy I'll use on exam day:**
#   - Draw a tiny compass marker on scratch paper next to the robot's current cell.
#   - Update the compass *before* updating the position on every rotation.
#   - Treat each `MOVE_FORWARD` as: "look at the compass, then move one cell in that direction."
#
# **Visual mental model I now use:**
#
# ```
#          N (↑)
#           │
#   W (←) ──+── E (→)
#           │
#          S (↓)
#
# Rotate LEFT  : N → W → S → E → N
# Rotate RIGHT : N → E → S → W → N
# ```
#
# </div>

# %% [markdown]
# <div class="qcard">
# <h3>Q43 — Fault-Tolerance Network Graph <span class="badge miss">Missed</span></h3>
#
# - **What it tested:** Given a network graph, decide which pair of node failures still allows A to reach F (i.e., which pair of failures the network is *fault-tolerant* against).
# - **My first instinct (wrong):** Selected B — "B and E fail → A cannot reach F" — confusing *non-fault-tolerant* with *fault-tolerant*.
# - **The fix in my head:** A network is *fault-tolerant against a failure* only if **a path still exists after the failure**. The question asks which failure pair the network *survives*, not which one breaks it.
# - **How I'll improve:** Re-read the stem twice on graph questions. Underline whether it's asking:
#   - "…still functions / can still send data" → look for pairs where a path **remains**, OR
#   - "…cannot reach / fails" → look for pairs where **all paths** are cut.
# - **Tracing strategy:** For each candidate pair, mentally delete those two nodes and *redraw* the remaining graph; then visually check for at least one A→F path.
#
# </div>

# %% [markdown]
# ## What These Misses Have In Common
#
# <div class="callout warn">
# <strong>Pattern</strong>
# Every miss came from <i>rushing a precision step</i> — not from missing concepts. The conceptual questions (impact of computing, internet/networking definitions, abstraction theory) were essentially flawless.
# </div>
#
# - **Q5** → rushed past the word "called once" without thinking about where duplication actually lives.
# - **Q12** → rushed the flowchart trace.
# - **Q28** → rushed picking inputs to test instead of thinking about which inputs would *force* the bug to surface.
# - **Q27 / Q40** → rushed orientation updates.
# - **Q43** → rushed reading the stem and conflated fault-tolerant with non-fault-tolerant.
#
# ### Where I'm losing points (qualitative)
#
# <div class="bar-row"><div class="bar-label">Concept knowledge</div><div class="bar-track"><div class="bar-fill full" style="width:98%"></div></div><div class="bar-value">Solid</div></div>
# <div class="bar-row"><div class="bar-label">Code tracing</div><div class="bar-track"><div class="bar-fill" style="width:88%"></div></div><div class="bar-value">Mostly</div></div>
# <div class="bar-row"><div class="bar-label">Flowchart tracing</div><div class="bar-track"><div class="bar-fill warn" style="width:72%"></div></div><div class="bar-value">Slow it</div></div>
# <div class="bar-row"><div class="bar-label">Bug-hunt input choice</div><div class="bar-track"><div class="bar-fill warn" style="width:65%"></div></div><div class="bar-value">Reverse</div></div>
# <div class="bar-row"><div class="bar-label">Robot grid orientation</div><div class="bar-track"><div class="bar-fill bad" style="width:55%"></div></div><div class="bar-value">Compass</div></div>
# <div class="bar-row"><div class="bar-label">Stem-reading on graphs</div><div class="bar-track"><div class="bar-fill warn" style="width:68%"></div></div><div class="bar-value">Verb</div></div>

# %% [markdown]
# ## MCQ Improvement Plan
#
# <div class="qcard fix">
#
# - **Daily until exam day:** 5 robot-grid trace problems, with the compass marker.
# - **Every other day:** 3 flowchart conversion problems (rewrite the flowchart as nested `if/else` on paper).
# - **Once a week:** A timed full 70-question MCQ set; review **every Skill 2.B ("determine the result") and Skill 4.C ("identify and correct errors")** question regardless of correctness.
# - **Quick-reference card I'm building:** binary↔decimal mental math, abstraction = "one procedure, many calls", fault-tolerance verb cues, robot rotation directions.
# - **Time-budget rule:** conceptual questions ≤ 30 s; tracing questions get a deliberate **45–60 s minimum** so I don't speed-skip the precision step.
#
# </div>

# %% [markdown]
# <div class="divider">Section 2 · FRQ Self-Grading</div>
#
# # 📝 FRQ Self-Grading (CollegeBoard Rubric)
#
# ## My FRQ Submission
#
# <div class="callout success">
# <strong>Project: 🌌 StarMatch</strong>
# A stargazing planner that ranks celestial objects by how worthwhile they are to observe tonight, given the user's experience, sky conditions, available time, and current month. Written in Python.
# </div>
#
# **Components used to satisfy the rubric:**
#
# - A **list** (`celestial_objects`) where each element is a dictionary of an object's attributes.
# - A **student-developed procedure** (`calculate_viewing_score`) with **5 parameters** and an internal structure that uses **sequencing, selection (multiple `if/elif/else`), and iteration (`for` loop)**.
# - A **call site** in `main()` that passes arguments to the procedure inside another `for` loop over the list.

# %% [markdown]
# ## Self-Score vs. CollegeBoard Rubric
#
# <div class="stat-grid">
#   <div class="stat-card good"><div class="stat-label">Self-Score</div><div class="stat-value">8 / 8</div></div>
#   <div class="stat-card score"><div class="stat-label">Expected</div><div class="stat-value">100%</div></div>
#   <div class="stat-card"><div class="stat-label">Rubric Rows</div><div class="stat-value">8</div></div>
#   <div class="stat-card"><div class="stat-label">Status</div><div class="stat-value" style="color:#4ade80">🟢 Full</div></div>
# </div>
#
# | Row | Rubric Requirement | My Evidence | Score |
# |-----|--------------------|-------------|-------|
# | **1** | Program with a function that has at least one parameter, AND a call to it | `calculate_viewing_score(obj, current_month, experience, minutes_available, pollution_level)` defined; called inside `main()` for every `obj` in the list | **1 / 1** ✅ |
# | **2** | The procedure contributes to the program's intended purpose | Without `calculate_viewing_score`, there is no ranking, no scoring, no "top 5" — the procedure literally drives the program's purpose | **1 / 1** ✅ |
# | **3** | Procedure body contains **sequencing, selection, AND iteration** | Sequencing (assignments line by line), selection (multiple `if/elif/else` chains), iteration (`for m in obj["best_months"]`) | **1 / 1** ✅ |
# | **4** | A list (or other collection type) is used to manage complexity | `celestial_objects` is a list of 12 dictionaries; without it, every object's data would be hard-coded as 12 separate variable sets | **1 / 1** ✅ |
# | **5** | Written Response — input, output, and how data was used | Inputs (month, experience, minutes, pollution) → top-5 ranked output | **1 / 1** ✅ |
# | **6** | Iteration question — describe behavior at boundary inputs | Loop runs zero times only if `best_months` is empty — explained why my data prevents this | **1 / 1** ✅ |
# | **7** | Two calls that produce **different** results, with justification | Saturn = **105**, Whirlpool = **0**, full arithmetic shown | **1 / 1** ✅ |
# | **8** | Benefit of using the procedure | **Abstraction / modularity** — concrete maintenance scenario | **1 / 1** ✅ |
# | **TOTAL** | **8 / 8 (Full Credit)** | | **🟢 8 / 8** |
#
# <div class="bar-row"><div class="bar-label">Row 1 — Procedure + call</div><div class="bar-track"><div class="bar-fill full" style="width:100%"></div></div><div class="bar-value">1/1</div></div>
# <div class="bar-row"><div class="bar-label">Row 2 — Procedure purpose</div><div class="bar-track"><div class="bar-fill full" style="width:100%"></div></div><div class="bar-value">1/1</div></div>
# <div class="bar-row"><div class="bar-label">Row 3 — Seq / sel / iter</div><div class="bar-track"><div class="bar-fill full" style="width:100%"></div></div><div class="bar-value">1/1</div></div>
# <div class="bar-row"><div class="bar-label">Row 4 — List manages complexity</div><div class="bar-track"><div class="bar-fill full" style="width:100%"></div></div><div class="bar-value">1/1</div></div>
# <div class="bar-row"><div class="bar-label">Row 5 — Input / output</div><div class="bar-track"><div class="bar-fill full" style="width:100%"></div></div><div class="bar-value">1/1</div></div>
# <div class="bar-row"><div class="bar-label">Row 6 — Iteration boundary</div><div class="bar-track"><div class="bar-fill full" style="width:100%"></div></div><div class="bar-value">1/1</div></div>
# <div class="bar-row"><div class="bar-label">Row 7 — Two different calls</div><div class="bar-track"><div class="bar-fill full" style="width:100%"></div></div><div class="bar-value">1/1</div></div>
# <div class="bar-row"><div class="bar-label">Row 8 — Procedure benefit</div><div class="bar-track"><div class="bar-fill full" style="width:100%"></div></div><div class="bar-value">1/1</div></div>

# %% [markdown]
# ## Each Rubric Row, Explained Thoroughly

# %% [markdown]
# <div class="qcard fix">
# <h3>Row 1 — Procedure With a Parameter, and a Call to It</h3>
#
# - **What CollegeBoard wants:** A student-defined procedure (not a built-in like `print` or `len`) that takes at least one parameter, plus a place in the program that *calls* that procedure.
# - **What I have:** `calculate_viewing_score(obj, current_month, experience, minutes_available, pollution_level)` — five parameters, well above the minimum of one. The call appears inside `main()` once per object: `score = calculate_viewing_score(obj, month, experience, minutes, pollution)`.
# - **Why it satisfies the row:** The definition is mine; the parameters genuinely *flow* (each one is used inside the body); the call passes real arguments computed from user input plus list iteration.
#
# </div>
#
# <div class="qcard fix">
# <h3>Row 2 — The Procedure Contributes to the Program's Purpose</h3>
#
# - **What CollegeBoard wants:** The procedure must do real work toward the program's *stated* purpose — not a throwaway helper.
# - **My program's purpose:** Rank celestial objects by tonight's worthwhileness for the user.
# - **What the procedure does:** It computes the very score that the ranking is built on. Remove it, and there is literally nothing to sort by.
# - **Why this is rock-solid:** The procedure is the *engine* of the program; everything else (input, list iteration, sorting, output) just feeds it or consumes its return value.
#
# </div>
#
# <div class="qcard fix">
# <h3>Row 3 — Sequencing, Selection, AND Iteration Inside the Procedure</h3>
#
# - **Sequencing:** `score = 50` → `month_match = False` → `for` loop → conditional adjustments → `if score < 0: score = 0` → `return score`.
# - **Selection:** Four distinct `if/elif/else` chains:
#   - In-season vs. out-of-season month
#   - Difficulty vs. user experience (3-way: easy, near-miss, way too hard)
#   - Light pollution levels (with a *nested* magnitude check inside the urban branch)
#   - Hard objects with not-enough-time penalty
# - **Iteration:** `for m in obj["best_months"]` — iterates over the list of best-viewing months for the object to test for an in-season match.
# - **Why this is rock-solid:** All three control structures live inside *one* student-developed procedure — exactly what Row 3 demands.
#
# </div>
#
# <div class="qcard fix">
# <h3>Row 4 — Using a List to Manage Complexity</h3>
#
# - **The list:** `celestial_objects` — 12 dictionaries, each describing one celestial object.
# - **Why it manages complexity:** Without the list, I'd need 12 separate sets of named variables (`orion_name`, `orion_type`, …, `lagoon_name`, `lagoon_type`, …). Adding a 13th object would require a new variable group AND new copy-pasted scoring logic. With the list, I add one dictionary entry — every loop, sort, and call automatically picks it up.
# - **Why this is rock-solid:** The list is *iterated*, *appended to* (in `scored_objects`), and *sorted* — all evidence of the list actively managing complexity, not just storing values.
#
# </div>
#
# <div class="qcard fix">
# <h3>Row 5 — Written Response: Input → Output</h3>
#
# - **Inputs (from `get_user_input`):** `month` (1–12), `experience` (1–5), `minutes_available` (positive int), `pollution_level` (1, 2, or 3).
# - **Output:** A ranked top-5 list, each entry showing the object's name, type, integer match score, and a fun fact.
# - **How data was used:** The four inputs flow into `calculate_viewing_score` for every object; returned scores are paired with the object via `scored_objects.append((obj, score))`; the list is sorted by score (descending); the top 5 are printed.
# - **Why this is rock-solid:** Every input is used; every output is justified by the data flow.
#
# </div>
#
# <div class="qcard fix">
# <h3>Row 6 — Iteration Boundary: Zero-Iteration Case</h3>
#
# - **The loop:** `for m in obj["best_months"]` inside the procedure.
# - **Zero-iteration condition:** Only if `obj["best_months"]` is an empty list `[]`.
# - **Why this never happens in my program:** Every entry in `celestial_objects` defines a non-empty `best_months` list (Orion has 5 months, Andromeda has 4, etc.). Under realistic program inputs, the loop **always executes at least once**.
# - **How I'll word it on the exam:** "There is no value of the parameters under normal program execution that causes the loop to execute zero times, because every object in `celestial_objects` is hard-coded with a non-empty `best_months` list. The only way to trigger zero iterations is to construct an artificial object with `best_months = []`."
#
# </div>
#
# <div class="qcard fix">
# <h3>Row 7 — Two Procedure Calls, Different Results</h3>
#
# <div class="compare">
#   <div class="card good">
#     <h4>🪐 Call A — Saturn</h4>
#     <code>calculate_viewing_score(Saturn, 7, 3, 60, 1)</code><br>
#     50 → in-season July <b>+30</b> → 80<br>
#     → difficulty 1 ≤ exp 3 <b>+15</b> → 95<br>
#     → pollution 1 (dark) <b>+10</b> → <b style="color:#4ade80">105</b>
#   </div>
#   <div class="card bad">
#     <h4>🌌 Call B — Whirlpool Galaxy</h4>
#     <code>calculate_viewing_score(Whirlpool, 2, 1, 20, 3)</code><br>
#     50 → out-of-season Feb <b>−20</b> → 30<br>
#     → diff 5 vs exp 1 (way harder) <b>−25</b> → 5<br>
#     → pollution 3, mag 8.4 > 3 <b>−30</b> → −25<br>
#     → diff ≥ 4 AND minutes 20 < 30 <b>−20</b> → −45<br>
#     → clamp <code>if score &lt; 0: score = 0</code> → <b style="color:#f87171">0</b>
#   </div>
# </div>
#
# - **Why this satisfies Row 7:** Same procedure, different parameter combinations, dramatically different outputs (105 vs. 0). Pre-computed arithmetic makes the explanation airtight — no hand-waving.
#
# </div>
#
# <div class="qcard fix">
# <h3>Row 8 — The Benefit of Using the Procedure</h3>
#
# - **Named benefit:** **Abstraction / modularity.**
# - **Concrete scenario:** If I want to change the scoring formula — say, reduce the in-season bonus from `+30` to `+20`, or add a brand-new factor ("phase of the Moon") — I edit *only* `calculate_viewing_score`. The 12 list entries stay untouched, and the `main()` call site stays untouched.
# - **Compare to without the procedure:** I would have to repeat the entire scoring logic inline for every object in the list — 12× the lines, 12× the places to edit, 12× the chances of a bug. That is exactly the maintainability anti-pattern Q5 of the MCQ tested.
# - **Why this is rock-solid:** It names the specific advantage AND ties it to a concrete maintenance scenario — which is what CollegeBoard scorers look for.
#
# </div>

# %% [markdown]
# <div class="divider">Section 3 · Code Walkthrough</div>
#
# # 🔬 Code Walkthrough — StarMatch
#
# ## High-Level Architecture
#
# ```
# ┌─────────────────────────────────────────────────────────────────┐
# │                         StarMatch Program                       │
# │                                                                 │
# │   ┌────────────────────┐                                        │
# │   │ celestial_objects  │  ← the LIST (Row 4)                    │
# │   │ [12 dictionaries]  │                                        │
# │   └─────────┬──────────┘                                        │
# │             │                                                   │
# │             │ iterated by                                       │
# │             ▼                                                   │
# │   ┌────────────────────────────┐    ┌─────────────────────────┐ │
# │   │ get_user_input()           │───▶│ main()                  │ │
# │   │ - month                    │    │  for obj in objects:    │ │
# │   │ - experience               │    │    score = calculate_…  │ │
# │   │ - minutes                  │    │    append (obj, score)  │ │
# │   │ - pollution                │    │  sort by score desc     │ │
# │   └────────────────────────────┘    │  print top 5            │ │
# │                                     └────────────┬────────────┘ │
# │                                                  │ calls        │
# │                                                  ▼              │
# │                       ┌─────────────────────────────────────┐   │
# │                       │ calculate_viewing_score(...)        │   │
# │                       │  Rows 1, 2, 3 of the rubric         │   │
# │                       │   • sequencing                      │   │
# │                       │   • selection (if/elif/else x4)     │   │
# │                       │   • iteration (for m in best_months)│   │
# │                       │  returns int 0–100+                 │   │
# │                       └─────────────────────────────────────┘   │
# └─────────────────────────────────────────────────────────────────┘
# ```

# %% [markdown]
# ## Walkthrough by Component
#
# <div class="qcard fix">
# <h3>📦 <code>celestial_objects</code> (the list)</h3>
#
# - 12 entries, each a dictionary with keys: `name`, `type`, `best_months`, `difficulty`, `magnitude`, `fact`.
# - The mix is intentional: 5 planets, 3 nebulas, 3 star clusters, 2 galaxies. This guarantees variety in scoring across user inputs (no one set of inputs dominates).
# - Difficulty ranges 1–5; magnitude ranges from −4.0 (Venus, very bright) to 8.8 (Ring Nebula, very dim). This range is what makes the pollution penalty interesting — bright objects survive urban skies, dim ones don't.
#
# </div>
#
# <div class="qcard fix">
# <h3>⚙️ <code>calculate_viewing_score(...)</code> — the engine</h3>
#
# - **Initial value:** `score = 50` — neutral baseline so adjustments are easy to reason about.
# - **Step 1 — Iteration over `best_months`:** A `for` loop sets `month_match = True` if any best-viewing month equals the user's current month.
# - **Step 2 — Selection on month match:** `+30` if in-season, `−20` if out-of-season.
# - **Step 3 — Selection on difficulty vs. experience:**
#   - Difficulty ≤ experience → `+15` (well-matched).
#   - Exactly one above experience → `−5` (a stretch, but doable).
#   - Otherwise (way too hard) → `−25`.
# - **Step 4 — Selection on light pollution:**
#   - Dark sky (1) → `+10` to everything.
#   - Suburban (2) → no change (implicit `else`).
#   - Urban (3) → `−30` if `magnitude > 3` (dim), `−5` if `magnitude ≤ 3` (bright). **Nested** selection inside an outer selection.
# - **Step 5 — Selection on time-vs-difficulty:** Hard object (difficulty ≥ 4) AND short session (< 30 min) → `−20`.
# - **Step 6 — Floor clamp:** `if score < 0: score = 0`.
# - **Return:** Integer score.
#
# </div>
#
# <div class="qcard fix">
# <h3>⌨️ <code>get_user_input()</code></h3>
#
# - Prints the banner, reads four `int(input(...))` values, and returns them as a tuple.
# - Boundary trust: I don't validate inputs in this version — I rely on the rubric not requiring it. (If asked: I could add `assert 1 <= month <= 12`, but it's not part of the FRQ ask.)
#
# </div>
#
# <div class="qcard fix">
# <h3>🚀 <code>main()</code></h3>
#
# - Calls `get_user_input()` once.
# - **Outer iteration:** `for obj in celestial_objects:` — calls `calculate_viewing_score` once per object, paired into `(obj, score)` tuples in `scored_objects`.
# - **Sort:** `scored_objects.sort(key=lambda pair: pair[1], reverse=True)` — sort by score descending. The `reverse=True` is what gives "best first."
# - **Top-N print:** Pulls the top 5 (or fewer if the list is shorter) and prints name, type, score, and a fun fact for each.
#
# </div>

# %% [markdown]
# ## Where Each Rubric Element Lives in the Code
#
# | Rubric Element | File Location |
# |----------------|---------------|
# | **List declaration** | `celestial_objects = [ … 12 dicts … ]` near the top of the file |
# | **List used to manage complexity** | `for obj in celestial_objects:` and `scored_objects.append((obj, score))` inside `main()` |
# | **Procedure with parameters** | `def calculate_viewing_score(obj, current_month, experience, minutes_available, pollution_level):` |
# | **Procedure call** | `score = calculate_viewing_score(obj, month, experience, minutes, pollution)` inside `main()` |
# | **Sequencing** | Lines inside `calculate_viewing_score` from `score = 50` through `return score` |
# | **Selection** | All four `if/elif/else` chains inside `calculate_viewing_score` |
# | **Iteration** | `for m in obj["best_months"]:` inside `calculate_viewing_score` |

# %% [markdown]
# <div class="divider">Section 4 · Anticipated FRQ Questions</div>
#
# # 🎯 Anticipated CollegeBoard FRQ Questions About My Code
#
# These are the questions I expect (or at least guard against) on the actual exam, with the answers I would give.

# %% [markdown]
# <div class="qcard fix">
# <h3>Q · Describe the inputs and outputs of your program.</h3>
#
# - **Inputs:** Four integers from the user — `month` (1–12), `experience` (1–5), `minutes_available` (positive integer), `pollution_level` (1 = dark, 2 = suburban, 3 = urban).
# - **Outputs:** A ranked top-5 list of celestial objects. Each entry shows the object's name, type, integer match score, and a one-sentence fun fact.
# - **How they connect:** The four inputs are passed to `calculate_viewing_score` for every object in `celestial_objects`; the returned scores are sorted descending and the top 5 are printed.
#
# </div>
#
# <div class="qcard fix">
# <h3>Q · Describe a condition under which the iteration in your procedure runs zero times.</h3>
#
# - The loop `for m in obj["best_months"]` runs zero times **only if `obj["best_months"]` is an empty list `[]`**.
# - This **does not happen** under normal program execution because every entry in `celestial_objects` has a non-empty `best_months` list (every object I included has at least 3 best-viewing months).
# - The only way to force zero iterations would be to manually add an artificial object whose `best_months` is `[]` — which the program never does on its own.
#
# </div>
#
# <div class="qcard fix">
# <h3>Q · Provide two calls that produce different results, and justify them.</h3>
#
# <div class="compare">
#   <div class="card good">
#     <h4>Call A — Saturn → 105</h4>
#     <code>calculate_viewing_score(Saturn, 7, 3, 60, 1)</code><br>
#     Saturn in July (in-season, +30) → 80<br>
#     difficulty 1 ≤ experience 3 (+15) → 95<br>
#     pollution 1 (+10) → <b>105</b>
#   </div>
#   <div class="card bad">
#     <h4>Call B — Whirlpool → 0</h4>
#     <code>calculate_viewing_score(Whirlpool, 2, 1, 20, 3)</code><br>
#     Out-of-season (−20) → 30<br>
#     diff 5 vs exp 1 (−25) → 5<br>
#     pollution 3, mag 8.4 > 3 (−30) → −25<br>
#     diff ≥ 4 + minutes < 30 (−20) → −45<br>
#     clamp → <b>0</b>
#   </div>
# </div>
#
# - **Why they differ:** Different month / experience / pollution / time combinations route through different selection branches inside the procedure. Same procedure, different parameter values → different output.
#
# </div>
#
# <div class="qcard fix">
# <h3>Q · Explain a benefit of using the procedure compared to writing the logic inline.</h3>
#
# - **Abstraction.** The procedure lets the rest of the program stay simple: `main()` just says "score every object" without needing to know *how* scoring works.
# - **Maintainability.** If I change the scoring formula (e.g., add a Moon-phase penalty, or change the in-season bonus), I edit *one place*. Without the procedure, I'd have to copy the change into 12 separate per-object code blocks.
# - **Readability.** The intent of `main()` is clear at a glance — score, sort, print top 5 — without scoring math cluttering it.
#
# </div>
#
# <div class="qcard fix">
# <h3>Q · Identify where your program uses sequencing, selection, and iteration.</h3>
#
# - **Sequencing:** Inside `calculate_viewing_score`, statements execute top-to-bottom (initialize `score`, check month, check difficulty, check pollution, check time, clamp, return).
# - **Selection:** All four `if/elif/else` chains inside `calculate_viewing_score`, plus the nested `if obj["magnitude"] > 3` inside the pollution-3 branch.
# - **Iteration:** `for m in obj["best_months"]` inside `calculate_viewing_score`. (Bonus: `for obj in celestial_objects` inside `main()`.)
#
# </div>
#
# <div class="qcard fix">
# <h3>Q · How does the list manage complexity?</h3>
#
# - Without `celestial_objects`, every object's data would need its own set of named variables, AND the scoring logic would need to be repeated inline for every object — making the program both longer and harder to update.
# - With the list, adding a 13th celestial object means appending **one dictionary** to `celestial_objects`. Everything else (the loop in `main()`, the sort, the top-5 print) automatically picks it up — no other code changes are needed.
#
# </div>
#
# <div class="qcard fix">
# <h3>Q · Describe the data your list stores and how it's used.</h3>
#
# - **Stores:** Each list element is a dictionary representing one celestial object, with keys `name` (string), `type` (string), `best_months` (list of ints), `difficulty` (int 1–5), `magnitude` (float), and `fact` (string).
# - **Used:** In `main()`, the list is iterated to call `calculate_viewing_score` once per object; the resulting `(obj, score)` pairs are stored in another list (`scored_objects`), sorted by score, and the top entries are printed.
#
# </div>
#
# <div class="qcard fix">
# <h3>Q · Describe a potential pitfall or limitation of your program.</h3>
#
# - **No input validation.** Entering `month = 50` does not crash, but it produces nonsense scoring (every object treated as out-of-season).
# - **Possible improvement:** Add range validation (`1 <= month <= 12`, `1 <= experience <= 5`, etc.) before scoring.
# - **Why mention this?** It shows critical thinking about how the procedure could be hardened — exactly the kind of "benefits of decomposition + future improvements" mindset CollegeBoard rewards.
#
# </div>

# %% [markdown]
# <div class="divider">Section 5 · Exam-Day Strategy</div>
#
# # 📌 Exam-Day Strategy: Full-Score the Real FRQ
#
# ## Personalized Project Reference (PPR) — Exact Screenshots I'll Submit

# %% [markdown]
# <div class="compare">
#   <div class="card good">
#     <h4>📸 PPR Procedure 1 — the procedure itself</h4>
#     Screenshot <code>calculate_viewing_score</code> from <code>def calculate_viewing_score(...)</code> through <code>return score</code>.<br><br>
#     Shows: procedure name, <b>5 parameters</b>, the <code>for</code> loop (iteration), and multiple <code>if/elif/else</code> chains (selection).<br><br>
#     <b>Rule:</b> no comments allowed in PPR — strip them before screenshot.
#   </div>
#   <div class="card good">
#     <h4>📸 PPR Procedure 2 — the call site</h4>
#     Screenshot the block inside <code>main()</code> that calls <code>calculate_viewing_score(obj, month, experience, minutes, pollution)</code>.<br><br>
#     Shows the call clearly with arguments being passed.
#   </div>
# </div>
#
# <div class="compare">
#   <div class="card good">
#     <h4>📸 PPR List 1 — data stored</h4>
#     Screenshot the <code>celestial_objects = [ ... ]</code> declaration showing <b>at least 2 full dictionary entries</b> so the structure is unambiguous.<br><br>
#     Proves data is being <b>stored</b> in the list.
#   </div>
#   <div class="card good">
#     <h4>📸 PPR List 2 — list being used</h4>
#     Screenshot the <code>for obj in celestial_objects</code> loop in <code>main()</code>, including the <code>.append()</code> line and the sort.<br><br>
#     Proves the list is <b>actively used</b> to manage complexity, not just declared.
#   </div>
# </div>

# %% [markdown]
# ## Written Response Plan — Lock-In Answers
#
# <div class="qcard fix">
#
# - **Q1 (input/output):** Lead with the four specific inputs → explain the scoring path each input controls → end with the top-5 ranked output. Be precise about which variable controls which branch.
# - **Q2a (iteration — zero executions):** State plainly "no such values exist under normal program execution" and explain *why*: every `best_months` list is non-empty.
# - **Q2b (two calls, same procedure, different results):** Pre-compute the two example scores (Saturn 105 / Whirlpool 0). Show the arithmetic step by step. CollegeBoard rewards explicit reasoning over vague claims.
# - **Q2c (procedure advantage):** Name **abstraction / modularity**, then give a concrete maintenance scenario ("changing the scoring formula only requires editing one function instead of 12 inline copies").
#
# </div>
#
# ## General Exam-Day Rules I'm Locking In
#
# <div class="callout success">
# <strong>The golden rule</strong>
# Every claim in the FRQ written response should be backed by a name from the PPR — function name, parameter name, list name, or dictionary key — never "my code" or "the procedure" alone.
# </div>
#
# - **Never say "my code" generically.** Always reference specific line-level elements: `calculate_viewing_score`, `celestial_objects`, `obj["best_months"]`, `score`. Specificity = points.
# - **Always reference the parameter names from the PPR.** Not "the month input" — say `current_month`. Not "sky conditions" — say `pollution_level`.
# - **Quote my own variable names verbatim** when describing data flow.
# - **Show arithmetic explicitly** in Q2b. Don't say "the score would be lower" — write `50 + 30 + 15 + 10 = 105`.
# - **Don't add extras the rubric didn't ask for.** Tight, on-point answers score higher than padded ones.
# - **Re-read the prompt verbs** — same trick from the MCQ. "Identify" ≠ "Explain" ≠ "Describe."
# - **Submit clean PPR screenshots** (no comments, no debug prints, no stray code). The PPR is the only artifact they look at — make it match what I describe in the written response.

# %% [markdown]
# <div class="divider">Section 6 · Full FRQ Code</div>
#
# # 💻 Full FRQ Code — StarMatch
#
# <div class="callout note">
# <strong>Note</strong>
# Below is the complete code I submitted for the AP CSP FRQ Personalized Project Reference. Every rubric element (procedure, parameters, sequencing/selection/iteration, list managing complexity) is directly visible in this single file.
# </div>

# %%
# StarMatch: a stargazing planner that ranks celestial objects by how
# worthwhile they are to observe tonight, given the user's experience,
# sky conditions, available time, and current month.

# List of celestial objects, each stored as a dictionary of attributes.
celestial_objects = [
    {"name": "Orion Nebula",        "type": "Nebula",       "best_months": [11, 12, 1, 2, 3], "difficulty": 2, "magnitude": 4.0,  "fact": "A stellar nursery where new stars are forming right now."},
    {"name": "Andromeda Galaxy",    "type": "Galaxy",       "best_months": [9, 10, 11, 12],   "difficulty": 3, "magnitude": 3.4,  "fact": "On a collision course with the Milky Way in 4.5 billion years."},
    {"name": "Jupiter",             "type": "Planet",       "best_months": [1, 2, 3, 10, 11, 12], "difficulty": 1, "magnitude": -2.0, "fact": "Binoculars reveal its four largest moons, first seen by Galileo in 1610."},
    {"name": "Saturn",              "type": "Planet",       "best_months": [6, 7, 8, 9],      "difficulty": 1, "magnitude": 0.5,  "fact": "Its rings are visible through almost any small telescope."},
    {"name": "Pleiades Cluster",    "type": "Star Cluster", "best_months": [10, 11, 12, 1, 2], "difficulty": 1, "magnitude": 1.6,  "fact": "Also called the Seven Sisters, mentioned in ancient texts worldwide."},
    {"name": "Ring Nebula",         "type": "Nebula",       "best_months": [6, 7, 8, 9],      "difficulty": 4, "magnitude": 8.8,  "fact": "The expanding shell of a dying star, shaped like a smoke ring."},
    {"name": "Mars",                "type": "Planet",       "best_months": [11, 12, 1],       "difficulty": 2, "magnitude": -0.5, "fact": "Polar ice caps are visible during opposition events."},
    {"name": "Whirlpool Galaxy",    "type": "Galaxy",       "best_months": [3, 4, 5, 6],      "difficulty": 5, "magnitude": 8.4,  "fact": "Two galaxies caught mid-collision in a gravitational dance."},
    {"name": "Hercules Cluster",    "type": "Star Cluster", "best_months": [5, 6, 7, 8],      "difficulty": 3, "magnitude": 5.8,  "fact": "A globular cluster packed with hundreds of thousands of ancient stars."},
    {"name": "Venus",               "type": "Planet",       "best_months": [3, 4, 5, 9, 10, 11], "difficulty": 1, "magnitude": -4.0, "fact": "Goes through phases like the Moon when viewed through a telescope."},
    {"name": "Double Cluster",      "type": "Star Cluster", "best_months": [10, 11, 12, 1],   "difficulty": 2, "magnitude": 3.7,  "fact": "Two open star clusters that look gorgeous side by side in binoculars."},
    {"name": "Lagoon Nebula",       "type": "Nebula",       "best_months": [6, 7, 8],         "difficulty": 3, "magnitude": 6.0,  "fact": "A massive star-forming region in the heart of Sagittarius."},
]

# Scores one object based on user inputs and returns an integer 0-100.
def calculate_viewing_score(obj, current_month, experience, minutes_available, pollution_level):
    score = 50

    # Iterate over the object's best months to check if it is in season.
    month_match = False
    for m in obj["best_months"]:
        if m == current_month:
            month_match = True

    # Reward in-season objects, penalize out-of-season ones.
    if month_match:
        score = score + 30
    else:
        score = score - 20

    # Match difficulty to user experience.
    if obj["difficulty"] <= experience:
        score = score + 15
    elif obj["difficulty"] == experience + 1:
        score = score - 5
    else:
        score = score - 25

    # Apply light pollution penalty for dim objects.
    if pollution_level == 1:
        score = score + 10
    elif pollution_level == 3:
        if obj["magnitude"] > 3:
            score = score - 30
        else:
            score = score - 5

    # Hard objects need real observation time.
    if obj["difficulty"] >= 4 and minutes_available < 30:
        score = score - 20

    if score < 0:
        score = 0

    return score

# Collect the four user inputs from the console.
def get_user_input():
    print("=" * 52)
    print("       STARMATCH - Tonight's Best Sky Targets")
    print("=" * 52)
    print()
    month = int(input("Current month (1-12): "))
    experience = int(input("Your experience (1=beginner, 5=expert): "))
    minutes = int(input("Minutes available to observe: "))
    pollution = int(input("Sky conditions (1=dark, 2=suburban, 3=urban): "))
    return month, experience, minutes, pollution

def main():
    month, experience, minutes, pollution = get_user_input()

    # Score every object and store (object, score) pairs.
    scored_objects = []
    for obj in celestial_objects:
        score = calculate_viewing_score(obj, month, experience, minutes, pollution)
        scored_objects.append((obj, score))

    # Sort highest score first.
    scored_objects.sort(key=lambda pair: pair[1], reverse=True)

    # Output the top 5 personalized recommendations.
    print()
    print("-" * 52)
    print("         YOUR PERSONALIZED VIEWING PLAN")
    print("-" * 52)
    top_n = 5
    if len(scored_objects) < top_n:
        top_n = len(scored_objects)

    for i in range(top_n):
        obj, score = scored_objects[i]
        print()
        print(str(i + 1) + ". " + obj["name"] + "  (" + obj["type"] + ")")
        print("   Match score: " + str(score) + "/100")
        print("   Did you know: " + obj["fact"])

    print()
    print("-" * 52)
    print("Clear skies!")

main()

# %% [markdown]
# ## Final Comments on the Code &amp; Strategies for Exam Day
#
# <div class="qcard fix">
# <h3>✅ Why this code is well-suited to score 8/8</h3>
#
# - The procedure has *5* parameters (one would have been enough).
# - The procedure body holds *all three* required control structures — sequencing, selection (multiple chains, including nested), iteration (`for m in obj["best_months"]`).
# - The list isn't decorative — it's iterated, appended to, and sorted; it is genuinely managing complexity.
# - The procedure is the *engine* of the program, not a side helper, satisfying Row 2 unambiguously.
#
# </div>
#
# <div class="qcard fix">
# <h3>🎯 Strategies I will execute on exam day</h3>
#
# - **Submit the cleanest PPR screenshots possible** — no comments (PPR forbids them), no leftover debug prints, no unused code. Code that is hard to read costs you points by accident.
# - **Mirror the screenshots in the written response** — when describing the procedure, use the *same* parameter names that appear in the screenshot. When describing the list, use *the same* dictionary key names (`best_months`, `difficulty`, `magnitude`).
# - **Show the arithmetic for Q2b** — pre-computing Saturn = 105 and Whirlpool = 0 turns a fuzzy explanation into a checkable proof.
# - **Anchor every claim to a code element.** Don't say "the program loops over data." Say "the `for obj in celestial_objects:` loop in `main()` calls `calculate_viewing_score` once per object."
# - **Stay disciplined on the verb in each prompt.** "Identify" → name it. "Describe" → name + 1–2 sentences. "Explain" → name + reasoning + concrete example.
# - **Time budget for FRQ:** First 5 min on PPR alignment (which screenshot maps to which row); next 20 min writing the response; last 5 min re-reading every paragraph for vague phrasing and replacing it with code-specific names.
#
# </div>
#
# <div class="callout success">
# <strong>Goal locked in 🚀</strong>
# <b>8 / 8</b> on the FRQ rubric and <b>~95%+</b> on the MCQ. The path there is precision under pressure — slow tracing on visual questions, specific names in written responses, clean screenshots in the PPR. Clear skies. 🔭
# </div>
